# %%
import numpy as np # linear algebra
import pandas as pd

# %%
        import os
        for dirname, _, filenames in os.walk('C:\Simplilearn\Python\Python projects\manage your finances using python'):
            for filename in filenames:
                print(os.path.join(dirname, filename))
# Out:
# C:\Simplilearn\Python\Python projects\manage your finances using python\2022-11-29 12-07-12.mp4
# C:\Simplilearn\Python\Python projects\manage your finances using python\2022-11-29 12-19-34.mp4
# C:\Simplilearn\Python\Python projects\manage your finances using python\2022-11-29 14-11-39.mp4
# C:\Simplilearn\Python\Python projects\manage your finances using python\Finance_data.csv
# C:\Simplilearn\Python\Python projects\manage your finances using python\Financial Analysis .ipynb
# C:\Simplilearn\Python\Python projects\manage your finances using python\new11.ipynb
# C:\Simplilearn\Python\Python projects\manage your finances using python\.ipynb_checkpoints\ finance analysis-checkpoint.ipynb
# C:\Simplilearn\Python\Python projects\manage your finances using python\.ipynb_checkpoints\Financial Analysis -checkpoint.ipynb
# C:\Simplilearn\Python\Python projects\manage your finances using python\.ipynb_checkpoints\new11-checkpoint.ipynb
# C:\Simplilearn\Python\Python projects\manage your finances using python\New folder\CreditCard.csv
# C:\Simplilearn\Python\Python projects\manage your finances using python\New folder\finance analysis.ipynb
# C:\Simplilearn\Python\Python projects\manage your finances using python\New folder\finance.py
# C:\Simplilearn\Python\Python projects\manage your finances using python\New folder\Financial Analysis using Python.pptx
# C:\Simplilearn\Python\Python projects\manage your finances using python\New folder\new.py
# C:\Simplilearn\Python\Python projects\manage your finances using python\New folder\new11.ipynb
# C:\Simplilearn\Python\Python projects\manage your finances using python\New folder\Original_data.csv
# C:\Simplilearn\Python\Python projects\manage your finances using python\New folder\savings acoount.csv
# C:\Simplilearn\Python\Python projects\manage your finances using python\New folder\tempCodeRunnerFile.py
# C:\Simplilearn\Python\Python projects\manage your finances using python\New folder\~$Financial Analysis using Python.pptx

# %%
        import os
        for dirname, _, filenames in os.walk('C:\Simplilearn\Python\Python projects\manage your finances using python'):
            for filename in filenames:
                print(os.path.join(dirname, filename))
# Out:
# C:\Simplilearn\Python\Python projects\manage your finances using python\2022-11-29 12-07-12.mp4
# C:\Simplilearn\Python\Python projects\manage your finances using python\2022-11-29 12-19-34.mp4
# C:\Simplilearn\Python\Python projects\manage your finances using python\2022-11-29 14-11-39.mp4
# C:\Simplilearn\Python\Python projects\manage your finances using python\Finance_data.csv
# C:\Simplilearn\Python\Python projects\manage your finances using python\Financial Analysis .ipynb
# C:\Simplilearn\Python\Python projects\manage your finances using python\new11.ipynb
# C:\Simplilearn\Python\Python projects\manage your finances using python\.ipynb_checkpoints\ finance analysis-checkpoint.ipynb
# C:\Simplilearn\Python\Python projects\manage your finances using python\.ipynb_checkpoints\Financial Analysis -checkpoint.ipynb
# C:\Simplilearn\Python\Python projects\manage your finances using python\.ipynb_checkpoints\new11-checkpoint.ipynb
# C:\Simplilearn\Python\Python projects\manage your finances using python\New folder\CreditCard.csv
# C:\Simplilearn\Python\Python projects\manage your finances using python\New folder\finance analysis.ipynb
# C:\Simplilearn\Python\Python projects\manage your finances using python\New folder\finance.py
# C:\Simplilearn\Python\Python projects\manage your finances using python\New folder\Financial Analysis using Python.pptx
# C:\Simplilearn\Python\Python projects\manage your finances using python\New folder\new.py
# C:\Simplilearn\Python\Python projects\manage your finances using python\New folder\new11.ipynb
# C:\Simplilearn\Python\Python projects\manage your finances using python\New folder\Original_data.csv
# C:\Simplilearn\Python\Python projects\manage your finances using python\New folder\savings acoount.csv
# C:\Simplilearn\Python\Python projects\manage your finances using python\New folder\tempCodeRunnerFile.py
# C:\Simplilearn\Python\Python projects\manage your finances using python\New folder\~$Financial Analysis using Python.pptx

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style('darkgrid')

# %%
df = pd.read_csv("C:\Simplilearn\Python\Python projects\manage your finances using python\Finance_data.csv")

# %%
df.head()
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0                 3               7    6     4  ...          1-3 years
# 1                 1               5    6     7  ...  More than 5 years
# 2                 2               5    1     7  ...          3-5 years
# 3                 7               6    4     5  ...   Less than 1 year
# 4                 6               4    5     7  ...   Less than 1 year
#
#   Invest_Monitor   Expect       Avenue What are your savings objectives?  \
# 0        Monthly  20%-30%  Mutual Fund                   Retirement Plan
# 1         Weekly  20%-30%  Mutual Fund                       Health Care
# 2          Daily  20%-30%       Equity                   Retirement Plan
# 3          Daily  10%-20%       Equity                   Retirement Plan
# 4          Daily  20%-30%       Equity                   Retirement Plan
#
#           Reason_Equity         Reason_Mutual     Reason_Bonds  \
# 0  Capital Appreciation        Better Returns  Safe Investment
# 1              Dividend        Better Returns  Safe Investment
# 2  Capital Appreciation          Tax Benefits  Assured Returns
# 3              Dividend  Fund Diversification   Tax Incentives
# 4  Capital Appreciation        Better Returns  Safe Investment
#
#              Reason_FD                    Source
# 0        Fixed Returns  Newspapers and Magazines
# 1  High Interest Rates     Financial Consultants
# 2        Fixed Returns                Television
# 3  High Interest Rates                  Internet
# 4            Risk Free                  Internet
#
# [5 rows x 24 columns]

# %%
df.drop(['Mutual_Funds', 'Equity_Market', 'Debentures', 'Government_Bonds', 'PPF', 'Fixed_Deposits',"Gold" ], axis = 1, inplace = True)

# %%
df = df.replace(r'^\s*$', np.nan, regex = True)

# %%
sns.countplot(x = 'gender', data = df, linewidth = 3, palette = "Set2", edgecolor = "black")
plt.show()

# %%
sns.countplot(x='age', data = df, palette = "Set3", linewidth = 2, edgecolor = "black")
plt.show()

# %%
plt.figure(figsize=(18,6))
plt.subplot(1,2,1)
sns.countplot(x=df['gender'], hue = df['Investment_Avenues'], palette = 'summer', linewidth = 3, edgecolor = "white")
plt.title("INVESTMENT AVENUE")

plt.subplot(1,2,2)
sns.countplot(x= df['gender'], hue = df['Stock_Marktet'], palette = 'hot', linewidth = 3, edgecolor = 'white')
plt.title("STOCK MARKET")
plt.show()

# %%
sns.countplot(x=df['Factor'], palette = 'coolwarm', linewidth = 2, edgecolor = "black")
plt.show()

# %%
plt.figure(figsize = (16,8))
sns.pointplot(x = "Purpose", y = "age", data = df, linestyles = "--", capsize = .3, color = "Blue")
plt.show()

# %%
plt.figure(figsize= (18,6))
plt.subplot(1,2,1)
sns.countplot(hue = df['gender'], x = df['Duration'], palette = 'viridis', linewidth = 2, edgecolor = "black" )
plt.title("DURATION")

plt.subplot(1,2,2)
sns.countplot(hue = df["gender"], x = df["Invest_Monitor"], palette = "seismic", linewidth = 2, edgecolor ="black")
plt.title("INVESTMENT MONITORING")
plt.show()

# %%
df.drop(['Mutual_Funds', 'Equity_Market',
       'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold'],axis=1,inplace=True)

# %%
df = df.replace(r'^\s*$', np.nan, regex=True)

# %%
sns.countplot(x ='gender', data = df, linewidth=3, palette="Set2",edgecolor='black')
plt.show()

# %%
sns.countplot(x='age', data = df, palette = "Set3", linewidth = 2, edgecolor = 'black')
plt.show()

# %%
plt.figure(figsize=(18,6))
plt.subplot(1, 2, 1)
sns.countplot(x=df['gender'],hue=df['Investment_Avenues'],palette='summer',linewidth=3,edgecolor='white')
plt.title('INVESTMENT AVENUE')
plt.subplot(1, 2, 2)
sns.countplot(x=df['gender'],hue=df['Stock_Marktet'],palette='hot',linewidth=3,edgecolor='white')
plt.title('STOCK MARKET')
plt.show()

# %%
sns.countplot(x= df['Factor'], palette = 'coolwarm', linewidth = 2, edgecolor = 'black')
plt.title("Gender")
plt.show()

# %%
sns.countplot(x= df["gender"], hue = df['Factor'], palette = "Oranges", linewidth = 2, edgecolor = "black")
plt.title("Gender")
plt.show()

# %%
plt.figure(figsize = (16,6))
sns.pointplot(x= "Purpose", y = 'age', data = df, linestyles = "--", capsize =.3, color = "Blue")
plt.show()

# %%
plt.figure(figsize=(18,6))
plt.subplot(1,2,1)
sns.countplot(hue= df['gender'], x= df['Duration'], palette = 'viridis', linewidth = 2, edgecolor = "black")
plt.title("DURATION")
plt.subplot(1,2,2)
sns.countplot(hue= df['gender'], x = df['Invest_Monitor'], palette = 'seismic', linewidth = 2, edgecolor= "black")
plt.title("INVESTMENT MONTORING")
plt.show()

# %%
sns.countplot(x ='age', data = df,palette="Set3",linewidth=2,edgecolor='black')
plt.show()

# %%
plt.figure(figsize=(18,6))
plt.subplot(1, 2, 1)
sns.countplot(x=df['gender'],hue=df['Investment_Avenues'],palette='summer',linewidth=3,edgecolor='white')
plt.title('INVESTMENT AVENUE')
plt.subplot(1, 2, 2)
sns.countplot(x=df['gender'],hue=df['Stock_Marktet'],palette='hot',linewidth=3,edgecolor='white')
plt.title('STOCK MARKET')
plt.show()

# %%
sns.countplot(x=df['Factor'],palette='coolwarm',linewidth=2,edgecolor='black')
# Out:
# <AxesSubplot: xlabel='Factor', ylabel='count'>

# %%
sns.countplot(x=df['gender'],hue=df['Factor'],palette='Oranges',linewidth=2,edgecolor='black')
plt.title('Gender')
plt.show()

# %%
plt.figure(figsize=(16,6))
sns.pointplot(x="Purpose",y='age',capsize=.3,data=df,linestyles="--",color='Blue')
plt.show()

# %%
plt.figure(figsize=(18,6))
plt.subplot(1, 2, 1)
sns.countplot(hue=df['gender'],x=df['Duration'],palette='viridis',linewidth=2,edgecolor='black')
plt.title('DURATION')
plt.subplot(1, 2, 2)
sns.countplot(hue=df['gender'],x=df['Invest_Monitor'],palette='seismic',linewidth=2,edgecolor='black')
plt.title('INVESTMENT MONITORING')
plt.show()
